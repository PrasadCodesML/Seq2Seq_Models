# %% [markdown]
# ### Decoder block contains of 3 blocks
#
# 1. Masked Self Attention
# 2. Cross Attention
# 3. Feed Forward Neural network
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Here we will consider training process
#
# We are consider machine translation task english to hindi
#
# The english sentence will go inside the encoder and uptill the hindi prediction starts encoder would have already be ready the contextual embeddings

# %% [markdown]
# ### Input block of decoder
#
# 1. Shiting
# 2. Tokenization
# 3. Embedding
# 4. Positional Encoding

# %% [markdown]
# ### Processing
#
# 5. Masked Multihead attention
# 6. Residual Connection addition
# 7. Layer Normalization
# 8. Cross Attention
# 9. Layer Normalization
# 10. FFNN (Architecture same as encoder)

# %% [markdown]
# ![WhatsApp Image 2025-03-13 at 05.28.43_03206228.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2025-03-13 at 05.28.44_e5c7410a.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2025-03-13 at 05.28.44_2136c584.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2025-03-13 at 05.28.44_6ff5d762.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2025-03-13 at 05.28.45_08680848.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
